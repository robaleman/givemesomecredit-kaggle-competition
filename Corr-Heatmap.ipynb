# %%
import pandas as pd
import  seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("whitegrid")
# %matplotlib inline

# %%
df = pd.read_csv("cs-training.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0           1                 1                              0.766127   45
# 1           2                 0                              0.957151   40
# 2           3                 0                              0.658180   38
# 3           4                 0                              0.233810   30
# 4           5                 0                              0.907239   49
#
#    NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 0                                     2   0.802982         9120.0
# 1                                     0   0.121876         2600.0
# 2                                     1   0.085113         3042.0
# 3                                     0   0.036050         3300.0
# 4                                     1   0.024926        63588.0
#
#    NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# ...

# %%
df["MonthlyIncome"]
# Out:
# 0          9120.0
# 1          2600.0
# 2          3042.0
# 3          3300.0
# 4         63588.0
# 5          3500.0
# 6             NaN
# 7          3500.0
# 8             NaN
# 9         23684.0
# 10         2500.0
# 11         6501.0
# 12        12454.0
# 13        13700.0
# 14            0.0
# 15        11362.0
# 16            NaN
# 17         8800.0
# 18         3280.0
# 19          333.0
# 20        12300.0
# 21         3000.0
# 22         2500.0
# 23         7916.0
# 24         2416.0
# 25         4676.0
# 26         8333.0
# 27         2500.0
# 28         3400.0
# 29         5500.0
#            ...
# 149970    15500.0
# 149971     5000.0
# 149972     6945.0
# 149973     5500.0
# 149974     5000.0
# 149975        NaN
# 149976        NaN
# 149977        NaN
# 149978     2500.0
# 149979     8700.0
# 149980     5525.0
# 149981     6849.0
# 149982     2760.0
# 149983     5000.0
# 149984        NaN
# 149985     1950.0
# 149986     5000.0
# 149987     3249.0
# 149988     7515.0
# ...

# %%
import  seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("whitegrid")
# %matplotlib inline

# %%
plt.figure(figsize=(14,10))
sns.heatmap(df.corr(),annot=True)

# %%
plt.figure(figsize=(14,10))
sns.lmplot(x="MonthlyIncome", y="SeriousDlqin2yrs", data=df)

# %%
import numpy as np
df["log_income"] = np.log(df["MonthlyIncome"])
df["log_debt"] = np.log(df["DebtRatio"])
# Out:
# /home/rob/.local/lib/python3.5/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log
#
# /home/rob/.local/lib/python3.5/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df.corr()
# Out:
#                                       Unnamed: 0  SeriousDlqin2yrs  \
# Unnamed: 0                              1.000000          0.002801
# SeriousDlqin2yrs                        0.002801          1.000000
# RevolvingUtilizationOfUnsecuredLines    0.002372         -0.001802
# age                                     0.004403         -0.115386
# NumberOfTime30-59DaysPastDueNotWorse   -0.000571          0.125587
# DebtRatio                              -0.002906         -0.007602
# MonthlyIncome                           0.002632         -0.019746
# NumberOfOpenCreditLinesAndLoans         0.004586         -0.029669
# NumberOfTimes90DaysLate                -0.001104          0.117175
# NumberRealEstateLoansOrLines           -0.000666         -0.007038
# NumberOfTime60-89DaysPastDueNotWorse   -0.000777          0.102261
# NumberOfDependents                     -0.000055          0.046048
# log_income                             -0.001231         -0.039615
# ...

# %%
df.corr

# %%
plt.figure(figsize=(14,10))
sns.relplot(y="log_debt", x="log_income", data=df)

# %%
sns.distplot(df["log_debt"])
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-14-bf1ba50b3fa3> in <module>()
# ----> 1 sns.distplot(df["log_debt"])
#
# /usr/local/lib/python3.5/dist-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     213     if hist:
#     214         if bins is None:
# --> 215             bins = min(_freedman_diaconis_bins(a), 50)
#     216         hist_kws.setdefault("alpha", 0.4)
#     217         if LooseVersion(mpl.__version__) < LooseVersion("2.2"):
#
# /usr/local/lib/python3.5/dist-packages/seaborn/distributions.py in _freedman_diaconis_bins(a)
#      37         return int(np.sqrt(a.size))
#      38     else:
# ---> 39         return int(np.ceil((a.max() - a.min()) / h))
#      40
#      41
#
# OverflowError: cannot convert float infinity to integer

# %%
sns.swarmplot(size=2, data=tone_matrix)

# %%
len(df["DebtRatio"])

# %%
len(df[df["DebtRatio"]>50000])

# %%
df[df["DebtRatio"]>50000]

# %%
np.mean(df["age"])

# %%
len(df[df["SeriousDlqin2yrs"] == 1])

# %%
len(df[df["SeriousDlqin2yrs"] == 0])

# %%
1+1
