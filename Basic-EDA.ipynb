# %% [markdown]
# # Exploratory Analysis: Feature Space

# %%
library(plyr)
library(ggplot2)

# %% [markdown]
# ## BASIC STATS

# %%
df <- read.csv("cs-training.csv")
head(df)
# Out:
#   X SeriousDlqin2yrs RevolvingUtilizationOfUnsecuredLines age
# 1 1 1                0.7661266                            45
# 2 2 0                0.9571510                            40
# 3 3 0                0.6581801                            38
# 4 4 0                0.2338098                            30
# 5 5 0                0.9072394                            49
# 6 6 0                0.2131787                            74
#   NumberOfTime30.59DaysPastDueNotWorse DebtRatio  MonthlyIncome
# 1 2                                    0.80298213  9120
# 2 0                                    0.12187620  2600
# 3 1                                    0.08511338  3042
# 4 0                                    0.03604968  3300
# 5 1                                    0.02492570 63588
# 6 0                                    0.37560697  3500
#   NumberOfOpenCreditLinesAndLoans NumberOfTimes90DaysLate
# 1 13                              0
# 2  4                              0
# ...

# %%
cor(na.omit(df))
# Out:
#                                      X             SeriousDlqin2yrs
# X                                     1.0000000000  0.004780773
# SeriousDlqin2yrs                      0.0047807731  1.000000000
# RevolvingUtilizationOfUnsecuredLines  0.0017874641 -0.002385507
# age                                   0.0050943302 -0.102684838
# NumberOfTime30.59DaysPastDueNotWorse -0.0018972171  0.123158970
# DebtRatio                            -0.0029490845 -0.003291309
# MonthlyIncome                         0.0026316894 -0.019745547
# NumberOfOpenCreditLinesAndLoans       0.0032007035 -0.027444592
# NumberOfTimes90DaysLate              -0.0024168170  0.111149321
# NumberRealEstateLoansOrLines         -0.0007007172 -0.003005088
# NumberOfTime60.89DaysPastDueNotWorse -0.0020499149  0.093835915
# NumberOfDependents                    0.0001701657  0.046704163
#                                      RevolvingUtilizationOfUnsecuredLines
# X                                     0.0017874641
# ...

# %%
for (i in 1:length(colnames(df))) {
    print( colnames(df)[i] )
    print ( summary(df[,i]) )
}
# Out:
# [1] "X"
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#       1   37501   75000   75000  112500  150000
# [1] "SeriousDlqin2yrs"
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
# 0.00000 0.00000 0.00000 0.06684 0.00000 1.00000
# [1] "RevolvingUtilizationOfUnsecuredLines"
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
#     0.00     0.03     0.15     6.05     0.56 50708.00
# [1] "age"
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#     0.0    41.0    52.0    52.3    63.0   109.0
# [1] "NumberOfTime30.59DaysPastDueNotWorse"
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   0.000   0.000   0.000   0.421   0.000  98.000
# [1] "DebtRatio"
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
#      0.0      0.2      0.4    353.0      0.9 329664.0
# [1] "MonthlyIncome"
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#       0    3400    5400    6670    8249 3008750   29731
# [1] "NumberOfOpenCreditLinesAndLoans"
# ...

# %%
quantile(df$DebtRatio, 0.9)
# Out:
#  90%
# 1267

# %% [markdown]
# ## FEATURE DENSITY / DIST PLOTS

# %%
df$SeriousDlqin2yrs <- factor(df$SeriousDlqin2yrs)
df <- na.omit(df)

# %%
plotBoxPlot <- function(feature) {
    ggplot(na.omit( df ), aes_string(x="SeriousDlqin2yrs", y=feature)) + 
    geom_boxplot(notch=FALSE)
    # ggtitle("Age density plots for defaulted and non-defaulted borrowers")
} 

#plotBoxPlot("age")

# %%
for (i in 1:length(colnames(df))) {
    feature = colnames(df)[i]
    print ( plotBoxPlot(feature) )
}
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %%
# plotFeatureDensity <- function(feature, outliers=FALSE) {
    
#     if (outliers) {    
#         x_min <- min(df[,feature])
#         x_max <- max(df[,feature])
#     }
    
#     else {
#         if (min(df[,feature]) < median(df[,feature]) - 3*sd(df[,feature])) {
#             x_min <- median(df[,feature]) - 3*sd(df[,feature])
#         }
#         else {
#             x_min <- min(df[,feature])
#         }
        
#         if (max(df[,feature]) > median(df[,feature]) + 3*sd(df[,feature])) {
#             x_max <- median(df[,feature]) + 3*sd(df[,feature])
#         }
#         else {
#             x_max <- max(df[,feature])
#         }
        
#     }
    
#     ggplot(df, aes_string(x=feature, color="SeriousDlqin2yrs")) + 
#     geom_density() + 
#     scale_color_discrete(name = "", breaks=c("0", "1"), labels=c("Did Not Default", "Defaulted"))  +
#     ggtitle(paste(feature, "density plots for defaulted and non-defaulted borrowers")) + 
#     theme(legend.position="top") +
#     xlim(x_min, x_max)

# }

# plotFeatureDensity2("age", outliers=TRUE)
# plotFeatureDensity2("age", outliers=FALSE)

# %%
plotFeatureDensity <- function(feature, outliers=FALSE) {
    
    if (outliers) {    
        x_min <- min(df[,feature])
        x_max <- max(df[,feature])
    }
    
    else {
        if (min(df[,feature]) < 0.5*quantile(df[,feature], 0.1) ) {
            x_min <- 0.5*quantile(df[,feature], 0.1)
        }
        else {
            x_min <- min(df[,feature])
        }
        
        if (max(df[,feature]) > 2*quantile(df[,feature], 0.9) ) {
            x_max <- 2*quantile(df[,feature], 0.9)
        }
        else {
            x_max <- max(df[,feature])
        }
        
    }
    
    ggplot(df, aes_string(x=feature, color="SeriousDlqin2yrs")) + 
    geom_density() + 
    scale_color_discrete(name = "", breaks=c("0", "1"), labels=c("Did Not Default", "Defaulted"))  +
    ggtitle(paste(feature, "density plots for defaulted and non-defaulted borrowers")) + 
    theme(legend.position="top") +
    xlim(x_min, x_max)

}

#plotFeatureDensity("age", outliers=TRUE)
#plotFeatureDensity("age", outliers=FALSE)

# %%
for (i in 3:length(colnames(df))) {
    feature = colnames(df)[i]
    print ( plotFeatureDensity2( feature, outliers=FALSE ) )
}
# Out:
# Warning message:
# “Removed 10470 rows containing non-finite values (stat_density).”Warning message:
# “Removed 1 rows containing non-finite values (stat_density).”
# plot without title
# Warning message:
# “Removed 2804 rows containing non-finite values (stat_density).”
# plot without title
# Warning message:
# “Removed 13352 rows containing non-finite values (stat_density).”
# plot without title
# Warning message:
# “Removed 6278 rows containing non-finite values (stat_density).”
# plot without title
# Warning message:
# “Removed 4410 rows containing non-finite values (stat_density).”
# plot without title
# Warning message:
# “Removed 6725 rows containing non-finite values (stat_density).”
# plot without title
# Warning message:
# “Removed 1265 rows containing non-finite values (stat_density).”
# plot without title
# Warning message:
# “Removed 6275 rows containing non-finite values (stat_density).”
# plot without title
# Warning message:
# ...

# %%
for (i in 3:length(colnames(df))) {
    feature = colnames(df)[i]
    print ( plotFeatureDensity2( feature, outliers=TRUE ) )
}
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
